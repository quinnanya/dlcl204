# %% [markdown]
# # File splitter notebook
# This notebook takes a large text file that has predictable sub-units (in this case, short stories separated by five blank lines), and splits it into those sub-units, naming each file by a cleaned-up version of the first line after the separator (which in this case, is the title).

# %% [markdown]
# ## Install and import libraries
# First, we install the `anyascii` library which takes non-ASCII characters and converts them to the closest ASCII. Then, we import that along with `re` (regular expressions, a fancy find-and-replace syntax) and `os` for navigating file paths.

# %%
import sys
# !{sys.executable} -m pip install anyascii

# %%
import re
import os
from anyascii import anyascii

# %% [markdown]
# ## Set up files & directories
# First, we define the directory where we'll be putting the split files. Then, we change locations into that directory. Finally, we define the full path to the file that we're splitting.

# %%
directory = '/Users/qad/Documents/ethan'
os.chdir(directory)
sourcefile = '/Users/qad/Documents/ethan/Cuentos completos - Emilia Pardo Bazan.txt'

# %% [markdown]
# ## Split the file
# The following cell actually splits the file after 5 blank lines (`\n`), then splits the title of the file (the immediately following line) off of that. It cleans up the title, then uses it to write the content of that section of the source (in this case, the short story).

# %%
#Opens the source file defined above
with open(sourcefile, 'r') as source:
    #Reads the source file
    text = source.read()
    #Splits the text based on 5 blank lines, then does the following for each of those chunks:
    for chapter in re.split(r'\n{5}', text):
        #Splits the title (the first line following the 5 blank lines)
        title = chapter.strip().split('\n')[0]
        #Shortens the title to 30 characters
        title = title[:30]
        #Makes the title all lowercase
        title = title.lower()
        #Turns the title into only ASCII characters
        title = anyascii(str(title))
        #Removes less than ideal characters that are still part of the title
        title = str(title).replace('<', '')
        title = str(title).replace('>', '')
        title = str(title).replace(' ', '-')
        #Prints the transformed title
        print(str(title))
        #Defines 'content' as the non-title portion of the text split by blank lines
        content = '\n'.join(chapter.strip().split('\n')[1:])
        #Creates a new file named for the title
        with open(f"{title}.txt", 'w') as _fh:
            #Writes the file
            _fh.write(content)
# Out:
# en-una-ocasion,-leopoldo-alas-
# emilia-pardo-bazan
# cuentos-completos
# epub-r1.0
# titulo-original:-cuentos-compl
# prologo-de-cuentos
# introduccion-de-las-obras-com
# las-recopilaciones
# la-dama-joven-y-otros-cuentos
# nieto-del-cid
# el-indulto
# fuego-a-bordo
# el-rizo-del-nazareno
# la-borgonona
# i
# ii
# primer-amor
# un-diplomatico
# sic-transit...
# el-premio-gordo
# una-pasion
# el-principe-amado
# ii
# iii
# la-gallega
# cuentos-escogidos
# travesura-pontificia
# planta-montes
# crimen-libre
# temprano-y-con-sol...
# cuentos-de-marineda
# por-el-arte
# morrion-y-boina
# las-tapias-del-campo-santo
# el-senor-doctoral
# en-el-nombre-del-padre...
# el-mechon-blanco
# ?cobardia?
# cuentos-nuevos
# cuentos-de-navidad
# ii
# iii
# iv
# v
# vi
# vii
# viii
# las-dos-vengadoras
# la-mariposa-de-pedreria
# el-ruido
# remordimiento
# agravante
# la-hierba-milagrosa
# publicada-esta-carta-con-el-cu
# sobremesa
# evocacion
# confidencia
# pina
# la-calavera
# cuatro-socialistas
# el-tesoro
# la-paloma-negra
# sedano
# el-milagro-del-hermanuco
# madre
# cuento-primitivo
# la-cena-de-cristo
# apostasia
# santiago-el-mudo
# la-flor-de-la-salud
# la-flor-seca
# la-cruz-roja
# linda
# rosquilla-de-monja...
# georgicas
# el-voto
# los-huevos-arrefalfados
# el-baile-del-querubin
# naufragas
# el-tornado
# coleccionista
# paracaidas
# la-cita
# en-verso
# arco-iris-(cuentos)
# viernes-santo
# el-talisman
# la-caja-de-oro
# el-decimo
# prueba-al-canto
# benito-de-palermo
# cuento-inmoral
# sinfonia-belica
# la-cabeza-a-componer
# cuentos-de-amor
# prefacio
# el-amor-asesinado
# el-viajero
# el-corazon-perdido
# mi-suicidio
# la-ultima-ilusion-de-don-juan
# desquite
# el-domino-verde
# la-aventura-del-angel
# el-fantasma
# la-perla-rosa
# un-parecido
# memento
# la-sirena
# asi-y-todo...
# la-cabellera-de-laura
# el-delincuente-honrado
# la-inspiracion
# champagne
# sor-aparicion
# ?justicia?
# mas-alla
# la-culpable
# la-novia-fiel
# afra
# cuento-sonado
# los-buenos-tiempos
# sara-y-agar
# maldicion-de-gitana
# la-bicha
# sangre-del-brazo
# consuelo
# la-novela-de-raimundo
# el-encaje-roto
# martina
# apologo
# a-secreto-agravio...
# la-religion-de-gonzalo
# el-panorama-de-la-princesa
# si,-senor
# cuentos-sacro-profanos
# prologo
# la-sed-de-cristo
# las-tijeras
# el-palacio-de-artasar
# el-nino-de-san-antonio
# la-mascara
# miguel-y-jorge
# corpus
# el-cuarto...
# el-martirio-de-sor-viviana
# los-hilos
# posesion
# la-logica
# el-aviso
# sequia
# desde-afuera
# el-pecado-de-yemsid
# omnia-vincit
# la-penitencia-de-dora
# ceniza
# las-cerezas
# el-santo-grial
# reconciliacion
# la-moneda-del-mundo
# entrada-de-ano
# tiempo-de-animas
# el-antepasado
# la-comedia-piadosa
# ii
# iii
# iv
# la-operacion
# vidrio-de-colores
# el-peregrino
# desde-alla
# un-destripador-de-antano
# un-destripador-de-antano
# i
# ii
# iii
# iv
# la-mayorazga-de-bouzas
# madre-gallega
# el-pinar-del-tio-ambrosio
# poema-humilde
# la-amenaza
# que-vengan-aqui...
# el-trueque
# la-camarona
# el-tetrarca-en-la-aldea
# pena-de-muerte
# barbastro
# ocho-nueces
# nuestro-senor-de-las-barbas
# la-santa-de-karnar
# ii
# de-polizon
# las-setas
# saletita
# la-redada
# la-oreja-de-juan-soldado
# en-tranvia
# en-tranvia
# adriana
# vitorio
# las-desnudas
# semilla-heroica
# justiciero
# eleccion
# la-chucha
# el-vino-del-mar
# la-paz
# suerte-macabra
# el-guardapelo
# la-ventana-cerrada
# infidelidad
# vendeana
# ley-natural
# el-comadron
# el-voto-de-rosina
# vivo-retrato
# la-punalada
# en-el-santo
# santos-bueno
# sustitucion
# la-compana
# la-dentadura
# inspiracion
# oscuramente
# el-ahogado
# el-molino
# aventura
# el-oficio-de-difuntos
# juan-trigo
# el-camafeo
# voz-de-la-sangre
# cuentos-de-navidad-y-reyes
# la-nochebuena-del-papa
# la-tentacion-de-sor-maria
# la-navidad-del-peludo
# nochebuena-del-jugador
# de-navidad
# jesus-en-la-tierra
# jesusa
# el-belen
# pagina-suelta
# dos-cenas
# la-nochebuena-del-carpintero
# el-ciego
# los-magos
# suenos-regios
# la-vision-de-los-reyes-magos
# el-rompecabezas
# en-semana-santa
# la-oracion-de-semana-santa
# cuentos-de-la-patria
# vengadora
# el-catecismo
# el-caballo-blanco
# la-exangue
# la-armadura
# el-torreon-de-la-esperanza
# el-palacio-frio
# el-templo
# el-milagro-de-la-diosa-durga
# entre-razas
# cuentos-antiguos
# la-paloma
# prejaspes
# zenana
# la-gota-de-cera
# la-palinodia
# el-mandil-de-cuero
# los-cabellos
# el-buen-callar...
# fausto-y-dafrosa
# lecciones-de-literatura
# la-guija
# la-sombra
# la-muerte-de-la-serpentina
# el-panuelo
# la-sor
# el-rival
# accidente
# el-destino
# la-paloma-azul
# los-adorantes
# curado
# el-deposito
# el-alambre
# el-fondo-del-alma
# (cuentos-del-terruno)
# el-fondo-del-alma
# el-xeste
# consuelos
# lelina
# cuesta-abajo
# dalinda
# la-cruz-negra
# ardid-de-guerra
# inutil
# la-capitana
# el-montero
# vampiro
# los-de-entonces
# siglo-xiii
# los-padres-del-santo
# (profesiones)
# paternidad
# restoran
# irracional
# perlista
# (interiores)
# bromita
# eximente
# las-vistas
# las-caras
# por-dentro
# la-enfermera
# la-enfermera
# el-revolver
# el-gemelo
# de-un-nido
# el-quinto
# la-argolla
# tio-terrones
# sin-respuesta
# un-duro-falso
# las-veintisiete
# vocacion
# vocacion
# el-gusanillo
# el-tapiz
# sud-expres
# sud-expres
# en-babilonia
# la-risa
# john
# gloriosa-viudez
# salvamento
# jactancia
# otro-anito
# el-engano
# la-niebla
# la-verguenza
# el-abanico
# la-mirada
# deber
# solucion
# heno
# sin-esperanza
# un-sistema
# aire
# los-cinco-sentidos
# por-espana
# diptico
# tia-celesta
# el-mundo
# el-disfraz
# mal-de-ojo
# el-espectro
# el-mausoleo
# los-cirineos
# paria
# siguiendole
# sin-pasion
# los-rizos
# implacable-kronos
# primaveral-moderna
# casi-artista
# la-clave
# feminista
# la-boda
# los-escarmentados
# cuentos-tragicos
# el-pozo-de-la-vida
# la-mosca-verde
# el-aljofar
# la-cana
# nube-de-paso
# drago
# la-tigresa
# durante-el-entreacto
# la-resucitada
# el-tesoro-de-los-lagidas
# dura-lex
# el-peligro-del-rostro
# recompensa
# dioses
# idilio
# por-otro
# la-madrina
# el-pajarraco
# la-leyenda-de-la-torre
# la-almohada
# hijo-del-alma
# arena
# argumento
# la-pasarela
# doradores
# cuentos-de-la-tierra
# las-medias-rojas
# un-poco-de-ciencia
# sin-querer
# la-corpana
# lumbrarada
# la-advertencia
# obra-de-misericordia
# bajo-la-losa
# milagro-natural
# la-casa-del-sueno
# entre-humo
# la-senorita-aglae
# el-legajo
# como-la-luz
# el-ultimo-baile
# so-tierra
# madrugueiro
# la-deixada
# antiguamente
# atavismos
# en-silencio
# bohemia-en-prosa
# reconciliados
# la-salvacion-de-don-carmelo
# episodio
# ofrecido
# la-soledad
# eterna-ley
# el-escondrijo
# contra-treta
# santi-boniti
# responsable
# el-vidrio-roto
# el-invento
# la-hoz
# el-sonar-del-rio
# racimos
# el-aire-cativo
# dios-castiga
# la-ganadera
# cuentos-dispersos
# el-brasileno
# un-matrimonio-del-siglo-xix
# la-cigarrera
# la-cigarrera
# la-mina
# el-salon
# cornada
# el-toro-negro
# fantaseando
# el-nino-de-cera
# el-viejo-de-las-limas
# anacronismo
# el-lorito-real
# comedia
# la-maga-primavera
# carbon
# el-casamiento-del-diablo
# profecia-para-el-ano-de-1897
# banquete-de-boda
# al-anochecer
# la-ley-del-hombre
# un-naufrago
# cuento-de-mentiras
# los-dominos-de-encaje
# el-linaje
# la-lima
# los-zapatos-viejos
# el-contador
# caso
# cenizas
# el-alba-de-viernes-santo
# la-venganza-de-las-flores
# el-alma-de-sirena
# el-llanto
# porques
# el-sabio
# hallazgo
# los-ramilletes
# caso
# belona
# consejero
# el-balcon-de-la-princesa
# error-de-diagnostico
# la-emparedada
# un-solo-cabello
# el-rosario-de-coral
# el-conjuro
# el-frac
# en-el-pueblo
# fumando
# la-aventura
# la-centenaria
# la-turquesa
# las-cerezas-rojas
# los-pendientes
# por-gloria
# traspaso
# una-voz
# chachara-de-horas
# el-puno
# fraternidad
# la-adaptacion
# las-cutres
# leccion
# los-novios-de-pastaflora
# no-lo-invento
# presentido
# rabeno
# cometaria
# el-cabalgador
# la-comoda
# cuento-de-navidad
# el-hombre-cerdo
# el-conde-llora
# el-conde-suena
# el-zapato
# la-confianza
# reina
# cena-de-navidad
# supersticion
# el-error-de-las-hadas
# filosofias
# lo-imposible
# los-santos-reyes
# pelegrin
# el-morito
# casualidad
# chucho
# compatibles
# el-honor
# gipsy
# los-de-manana
# los-dulces-del-ano
# padre-e-hijo
# instintivo
# la-cordonera
# la-estrella-blanca
# la-invisible
# la-punta-del-cigarro
# la-puntilla
# punteria
# los-anos-rojos
# en-el-presidio
# el-mascaron
# femeninas
# en-su-cama
# la-danza-del-peregrino
# sin-tregua
# instinto
# un-buen-tirito
# dialogo
# pilarito
# el-desparecido
# testigo-irrecusable
# la-conquista-de-la-cena
# el-panteon-de-los-anos
# el-caliz
# ejemplo
# el-enemigo
# el-espiritu-del-conde
# el-triunfo-de-baltasar
# inutil
# interrogante
# la-zurcidora
# galana-y-relucia
# a-lo-vivo
# el-viaje-de-don-casiano
# la-cuba
# teorias
# el-alma-de-candido
# el-engendro
# maleficio
# el-nino
# el-paraguas
# el-te-de-las-convalecientes
# la-navidad-del-pavo
# las-espinas
# el-vencedor
# el-crimen-del-ano-viejo
# el-azar
# el-arbol-rosa
# el-testamento-del-ano
# la-muchedumbre
# lo-que-los-reyes-traian
# dialogo-secular
# navidad-de-lobos
# agueda
# corro-de-sombras
# el-arco
# el-clavo
# la-cola-del-pan
# las-siete-dudas
# volunto
# emilia-pardo-bazan,-(la-coruna
# notas
